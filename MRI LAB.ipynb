# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import dicom

RefDs = dicom.read_file('IM_0001.dcm')

print(RefDs)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M_FFE', 'M', 'FFE']
# (0008, 0012) Instance Creation Date              DA: '20171115'
# (0008, 0013) Instance Creation Time              TM: '111930'
# (0008, 0014) Instance Creator UID                UI: 1.3.46.670589.11.34055.5
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.46.670589.11.34055.5.0.4164.2017111510332759006
# (0008, 0020) Study Date                          DA: '20171115'
# (0008, 0021) Series Date                         DA: '20171115'
# (0008, 0022) Acquisition Date                    DA: '20171115'
# (0008, 0023) Content Date                        DA: '20171115'
# (0008, 0030) Study Time                          TM: '102824'
# (0008, 0031) Series Time                         TM: '103220.85000'
# ...

# %%
from datetime import datetime

print('The image is '+str(RefDs.Rows)+'x'+str(RefDs.Columns)+' pixels')
print('The image was encoded with '+str(RefDs.BitsStored)+' bits ')
print('The manufacturer is '+str(RefDs.Manufacturer)+' and the model is '+str(RefDs.ManufacturersModelName))
d=datetime.strptime(RefDs.AcquisitionDate,'%Y%m%d')
print('The image was made on '+str(d.date()))
print('The anatomy imaged is '+str(RefDs.BodyPartExamined))
if RefDs.PatientsSex=='F':
    print('The patient imaged is Female')
else:
    print('The patient imaged is Male')
if RefDs.PatientsName=='':
    print('The patient\'s name is unkown')
else:
    print('The patient\'s name is '+str(RefDs.PatientsName))
# Out:
# The image is 256x256 pixels
# The image was encoded with 12 bits
# The manufacturer is Philips Medical Systems and the model is Achieva
# The image was made on 2017-11-15
# The anatomy imaged is BRAIN
# The patient imaged is Male
# The patient's name is res_watermelon

# %%
ConstPixelDims = (int(RefDs.Rows), int(RefDs.Columns))
ArrayDicom = np.zeros(ConstPixelDims, dtype=RefDs.pixel_array.dtype)
ds = dicom.read_file('IM_0001.dcm')
ArrayDicom[:,:]=ds.pixel_array

fig=plt.figure(figsize=(10, 10), dpi= 75, facecolor='w', edgecolor='k')
plt.axes().set_aspect('equal') 
plt.set_cmap(plt.gray()) 
x=np.arange(RefDs.Rows)
y=np.arange(RefDs.Columns)
plt.pcolormesh(x, y, np.flipud(ArrayDicom[:, :]))
plt.axis([x.min(),x.max(),y.min(),y.max()])
# Out:
# [0, 255, 0, 255]

# %%
print(str(RefDs.EchoTime))
print(str(RefDs.RepetitionTime))
print(str(RefDs.FlipAngle))
print(str(RefDs.ScanningSequence))
print(str(RefDs.AcquisitionMatrix))
# Out:
# 4.603
# 11
# 15
# GR
# [0, 256, 128, 0]

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import dicom

RefDs = dicom.read_file('IM_0101.dcm')

print(RefDs)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
# (0008, 0012) Instance Creation Date              DA: '20171115'
# (0008, 0013) Instance Creation Time              TM: '111930'
# (0008, 0014) Instance Creator UID                UI: 1.3.46.670589.11.34055.5
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.46.670589.11.34055.5.0.4164.2017111510454835099
# (0008, 0020) Study Date                          DA: '20171115'
# (0008, 0021) Series Date                         DA: '20171115'
# (0008, 0022) Acquisition Date                    DA: '20171115'
# (0008, 0023) Content Date                        DA: '20171115'
# (0008, 0030) Study Time                          TM: '102824'
# (0008, 0031) Series Time                         TM: '104429.39000'
# ...

# %%
from datetime import datetime

print('The image is '+str(RefDs.Rows)+'x'+str(RefDs.Columns)+' pixels')
print('The image was encoded with '+str(RefDs.BitsStored)+' bits ')
print('The manufacturer is '+str(RefDs.Manufacturer)+' and the model is '+str(RefDs.ManufacturersModelName))
d=datetime.strptime(RefDs.AcquisitionDate,'%Y%m%d')
print('The image was made on '+str(d.date()))
print('The anatomy imaged is '+str(RefDs.BodyPartExamined))
if RefDs.PatientsSex=='F':
    print('The patient imaged is Female')
else:
    print('The patient imaged is Male')
if RefDs.PatientsName=='':
    print('The patient\'s name is unkown')
else:
    print('The patient\'s name is '+str(RefDs.PatientsName))
# Out:
# The image is 512x512 pixels
# The image was encoded with 12 bits
# The manufacturer is Philips Medical Systems and the model is Achieva
# The image was made on 2017-11-15
# The anatomy imaged is BRAIN
# The patient imaged is Male
# The patient's name is res_watermelon

# %%
ConstPixelDims = (int(RefDs.Rows), int(RefDs.Columns))
ArrayDicom = np.zeros(ConstPixelDims, dtype=RefDs.pixel_array.dtype)
ds = dicom.read_file('IM_0101.dcm')
ArrayDicom[:,:]=ds.pixel_array

fig=plt.figure(figsize=(10, 10), dpi= 75, facecolor='w', edgecolor='k')
plt.axes().set_aspect('equal') 
plt.set_cmap(plt.gray()) 
x=np.arange(RefDs.Rows)
y=np.arange(RefDs.Columns)
plt.pcolormesh(x, y, np.flipud(ArrayDicom[:, :]))
plt.axis([x.min(),x.max(),y.min(),y.max()])
# Out:
# [0, 511, 0, 511]

# %%
print(str(RefDs.EchoTime))
print(str(RefDs.RepetitionTime))
print(str(RefDs.FlipAngle))
print(str(RefDs.ScanningSequence))
print(str(RefDs.SliceThickness))

print(str(RefDs.AcquisitionMatrix))
print(str(RefDs.PixelSpacing))
print(str(RefDs.SliceLocation))
# Out:
# 80
# 3000
# 90
# SE
# 5
# [0, 400, 319, 0]
# ['0.44921875', '0.44921875']
# 0
