# %%
# %matplotlib inline

import scipy as sci
import scipy.linalg
import numpy as np
import matplotlib.pyplot as plt

f = open('UltrasoundSampleSignal.dat','rb')
AllSignal = np.fromfile(f,count=-1,dtype=np.uint16)
x=np.arange(0,15000/125e6,1/125e6)  

for i in range(0,462):

    plt.plot(x,AllSignal[i*15000:(i+1)*15000])
    plt.title('All signal data')
    plt.xlabel('Time')
    plt.ylabel('Unsigned Integer Value')
    plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
    f.close()

# %%
# %matplotlib inline

import scipy as Sci
import scipy.linalg
import numpy as np
import pylab as pl
import matplotlib.pyplot as plt
f = open('UltrasoundSampleSignal.dat','rb')
AllSignal = np.fromfile(f,count=-1,dtype=np.uint16)
x=np.arange(0,15000/125e6,1/125e6)  
   
count = 0    

for i in range(0,462):

        plt.plot(x,AllSignal[i*15000:(i+1)*15000])
        plt.title('All signal data')
        plt.xlabel('Time')
        plt.ylabel('Unsigned Integer Value')
        plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))


for z in range(0,462):
    
        line=AllSignal[(z)*15000:(z+1)*15000]    
        dataF=line-np.mean(line)
        L=len(dataF)
        f=np.arange(0,125e6/2,125e6/15000)
        Y=np.fft.fft(dataF)
        PyyClean=abs(Y)/L
        peak = np.max(PyyClean)
         
        if peak > 800:
            
            print(z)
            
            count = count + 1
            inx=np.where(f>10e6)
            inx=inx[0]
            plt.subplot(122)
            plt.plot(f[:inx[0]], PyyClean[:inx[0]])    
            
print("total number of lines that were above threshold: ")            
print(count)
# Out:
# 109
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# total number of lines that were above threshold:
# 101
